# %%
# %run lib.ipynb
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("..")
from analysis_tools import KmerAligner
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = "../../NanoporeData/burnin_downloads/"
SRATE = 5000
NMERS = 5

# %%
files = !find {path} | grep fast5

# %%
ref = !cat ../../NanoporeData/LambdaReference/lambda_ref.fasta | grep -v ">"
ref = ref[0]

# %%
file_data = process_metrichor_files(files[40:100], verbose=True)
# Out:
# processing file 18 channel 104
# processing file 19 channel 104
# processing file 1 channel 104
# processing file 3 channel 104
# processing file 4 channel 104
# processing file 6 channel 104
# processing file 7 channel 104
# processing file 8 channel 104
# processing file 9 channel 104
# processing file 0 channel 105
# processing file 10 channel 105
# processing file 11 channel 105
# processing file 12 channel 105
# processing file 14 channel 105
# processing file 15 channel 105
# processing file 16 channel 105
# processing file 17 channel 105
# processing file 18 channel 105
# processing file 19 channel 105
# processing file 1 channel 105
# processing file 20 channel 105
# processing file 21 channel 105
# processing file 22 channel 105
# processing file 23 channel 105
# processing file 24 channel 105
# processing file 25 channel 105
# processing file 26 channel 105
# processing file 28 channel 105
# processing file 29 channel 105
# processing file 2 channel 105
# processing file 3 channel 105
# processing file 5 channel 105
# processing file 6 channel 105
# processing file 7 channel 105
# Empty file: ../../NanoporeData/burnin_downloads/IBIS218_010_059_ibisburnin_1700_1_ch105_file7_strand.fast5. Skipped.
# processing file 9 channel 105
# Empty file: ../../NanoporeData/burnin_downloads/IBIS218_010_059_ibisburnin_1700_1_ch105_file9_strand.fast5. Skipped.
# processing file 0 channel 106
# processing file 10 channel 106
# processing file 12 channel 106
# processing file 13 channel 106
# processing file 14 channel 106
# processing file 15 channel 106
# processing file 16 channel 106
# processing file 18 channel 106
# processing file 1 channel 106
# processing file 20 channel 106
# processing file 22 channel 106
# processing file 23 channel 106
# processing file 24 channel 106
# processing file 25 channel 106
# processing file 26 channel 106
# processing file 27 channel 106
# processing file 28 channel 106
# processing file 29 channel 106
# processing file 2 channel 106
# processing file 3 channel 106
# processing file 4 channel 106
# processing file 5 channel 106
# processing file 7 channel 106
# processing file 8 channel 106
# processing file 9 channel 106

# %%
NMER = 3
kmer_aligner = KmerAligner(ref, verbose = True, nmer=NMER)
# Out:
# Query Length 48502

# %%
true_events = []

for file in file_data:
    tmp_events = kmer_aligner.align_file(file)
    true_events.extend(tmp_events)
    
kmer_aligner.print_statistics()
# Out:
# processing ch 104 file 18
#
#         Start/End Query 26890/32703 Target 2/5637 Skipped 5
#         Length 5635/5640 Identity 0.25750
#
# processing ch 104 file 19
#
#         Start/End Query 11578/20191 Target 0/7179 Skipped 2
#         Length 7179/7181 Identity 0.31509
#
# processing ch 104 file 1
#
#         Start/End Query 2998/3133 Target 0/131 Skipped 2
#         Length 131/133 Identity 0.49618
#
# processing ch 104 file 3
#
#         Start/End Query 14580/20130 Target 1/5074 Skipped 2
#         Length 5073/5075 Identity 0.28070
#
# processing ch 104 file 4
#
#         Start/End Query 43021/47843 Target 1/4575 Skipped 3
#         Length 4574/4577 Identity 0.25120
#
# processing ch 104 file 6
#
#         Start/End Query 23494/32229 Target 1/8087 Skipped 4
#         Length 8086/8090 Identity 0.28135
#
# processing ch 104 file 7
#
#         Start/End Query 36798/38473 Target 1/1523 Skipped 2
#         Length 1522/1524 Identity 0.36925
#
# processing ch 104 file 8
#
#         Start/End Query 34346/40201 Target 2/5351 Skipped 4
#         Length 5349/5353 Identity 0.27687
#
# processing ch 104 file 9
#
#         Start/End Query 31983/39183 Target 4/6675 Skipped 5
#         Length 6671/6676 Identity 0.28302
#
# processing ch 105 file 0
#
#         Start/End Query 25919/31768 Target 0/5605 Skipped 1
#         Length 5605/5606 Identity 0.30919
#
# processing ch 105 file 10
#
#         Start/End Query 4069/13180 Target 1/8485 Skipped 2
#         Length 8484/8486 Identity 0.25578
#
# processing ch 105 file 11
#
#         Start/End Query 36615/37394 Target 0/705 Skipped 3
#         Length 705/708 Identity 0.34894
#
# processing ch 105 file 12
#
#         Start/End Query 31687/41496 Target 0/9249 Skipped 15749
#         Length 9249/24998 Identity 0.25916
#
# processing ch 105 file 14
#
#         Start/End Query 3070/12922 Target 0/9568 Skipped 4
#         Length 9568/9572 Identity 0.24436
#
# processing ch 105 file 15
#
#         Start/End Query 28199/34687 Target 3/6457 Skipped 4
#         Length 6454/6458 Identity 0.27735
#
# processing ch 105 file 16
#
#         Start/End Query 44957/48501 Target 0/3317 Skipped 57
#         Length 3317/3374 Identity 0.28761
#
# processing ch 105 file 17
#
#         Start/End Query 1/6072 Target 43/5866 Skipped 44
#         Length 5823/5867 Identity 0.29710
#
# processing ch 105 file 18
#
#         Start/End Query 41821/48499 Target 0/6042 Skipped 131
#         Length 6042/6173 Identity 0.28418
#
# processing ch 105 file 19
#
#         Start/End Query 27041/32949 Target 0/5568 Skipped 1
#         Length 5568/5569 Identity 0.26329
#
# processing ch 105 file 1
#
#         Start/End Query 22581/33922 Target 0/10636 Skipped 1
#         Length 10636/10637 Identity 0.27191
#
# processing ch 105 file 20
#
#         Start/End Query 44950/47225 Target 0/2158 Skipped 4
#         Length 2158/2162 Identity 0.29425
#
# processing ch 105 file 21
#
#         Start/End Query 0/8515 Target 0/8108 Skipped 3
#         Length 8108/8111 Identity 0.24975
#
# processing ch 105 file 22
#
#         Start/End Query 3568/10851 Target 3/7085 Skipped 5
#         Length 7082/7087 Identity 0.25374
#
# processing ch 105 file 23
#
#         Start/End Query 7851/13194 Target 3/5083 Skipped 7
#         Length 5080/5087 Identity 0.27598
#
# processing ch 105 file 24
#
#         Start/End Query 39619/40319 Target 1/637 Skipped 7
#         Length 636/643 Identity 0.33333
#
# processing ch 105 file 25
#
#         Start/End Query 40755/48498 Target 0/6416 Skipped 37
#         Length 6416/6453 Identity 0.28398
#
# processing ch 105 file 26
#
#         Start/End Query 27500/37090 Target 1/9060 Skipped 2
#         Length 9059/9061 Identity 0.25930
#
# processing ch 105 file 28
#
#         Start/End Query 29341/33623 Target 0/4047 Skipped 1
#         Length 4047/4048 Identity 0.26242
#
# processing ch 105 file 29
#
#         Start/End Query 19982/26616 Target 1/6020 Skipped 2
#         Length 6019/6021 Identity 0.26466
#
# processing ch 105 file 2
#
#         Start/End Query 1/5314 Target 14/4651 Skipped 15
#         Length 4637/4652 Identity 0.27065
#
# processing ch 105 file 3
#
#         Start/End Query 36198/43160 Target 2/6557 Skipped 6
#         Length 6555/6561 Identity 0.26819
#
# processing ch 105 file 5
#
#         Start/End Query 8283/13556 Target 0/5014 Skipped 2
#         Length 5014/5016 Identity 0.24751
#
# processing ch 105 file 6
#
#         Start/End Query 19054/24840 Target 2/5147 Skipped 3
#         Length 5145/5148 Identity 0.28086
#
# processing ch 106 file 0
#
#         Start/End Query 3094/12811 Target 1/9130 Skipped 4
#         Length 9129/9133 Identity 0.25107
#
# processing ch 106 file 10
#
#         Start/End Query 42413/48499 Target 3/5888 Skipped 41
#         Length 5885/5926 Identity 0.26950
#
# processing ch 106 file 12
#
#         Start/End Query 32623/35546 Target 0/2712 Skipped 1
#         Length 2712/2713 Identity 0.27987
#
# processing ch 106 file 13
#
#         Start/End Query 44960/48501 Target 3/3337 Skipped 74
#         Length 3334/3408 Identity 0.31794
#
# processing ch 106 file 14
#
#         Start/End Query 45143/48501 Target 2/3188 Skipped 74
#         Length 3186/3260 Identity 0.30979
#
# processing ch 106 file 15
#
#         Start/End Query 32192/35206 Target 6/2840 Skipped 8
#         Length 2834/2842 Identity 0.27699
#
# processing ch 106 file 16
#
#         Start/End Query 7372/11571 Target 0/3970 Skipped 1
#         Length 3970/3971 Identity 0.28489
#
# processing ch 106 file 18
#
#         Start/End Query 41169/45648 Target 0/4034 Skipped 1
#         Length 4034/4035 Identity 0.27764
#
# processing ch 106 file 1
#
#         Start/End Query 40814/45008 Target 1/3970 Skipped 2
#         Length 3969/3971 Identity 0.29126
#
# processing ch 106 file 20
#
#         Start/End Query 41703/46072 Target 0/4217 Skipped 4
#         Length 4217/4221 Identity 0.25421
#
# processing ch 106 file 22
#
#         Start/End Query 9420/23190 Target 2/13141 Skipped 1245
#         Length 13139/14384 Identity 0.24713
#
# processing ch 106 file 23
#
#         Start/End Query 16509/26158 Target 0/9114 Skipped 3
#         Length 9114/9117 Identity 0.26739
#
# processing ch 106 file 24
#
#         Start/End Query 1/6900 Target 40/6611 Skipped 41
#         Length 6571/6612 Identity 0.28808
#
# processing ch 106 file 25
#
#         Start/End Query 81/6109 Target 1/5474 Skipped 3
#         Length 5473/5476 Identity 0.27608
#
# processing ch 106 file 26
#
#         Start/End Query 41628/48500 Target 2/6528 Skipped 53
#         Length 6526/6579 Identity 0.30126
#
# processing ch 106 file 27
#
#         Start/End Query 36083/36173 Target 1/86 Skipped 4
#         Length 85/89 Identity 0.50588
#
# processing ch 106 file 28
#
#         Start/End Query 29614/33177 Target 2/3315 Skipped 3
#         Length 3313/3316 Identity 0.26864
#
# processing ch 106 file 29
#
#         Start/End Query 6362/12470 Target 3/5843 Skipped 4
#         Length 5840/5844 Identity 0.27705
#
# processing ch 106 file 2
#
#         Start/End Query 27214/33560 Target 1/6131 Skipped 2
#         Length 6130/6132 Identity 0.25791
#
# processing ch 106 file 3
#
#         Start/End Query 26834/33474 Target 0/6299 Skipped 1
#         Length 6299/6300 Identity 0.26052
#
# processing ch 106 file 4
#
#         Start/End Query 28185/31524 Target 1/2995 Skipped 4
#         Length 2994/2998 Identity 0.29125
#
# processing ch 106 file 5
#
#         Start/End Query 21334/26881 Target 4/5261 Skipped 6
#         Length 5257/5263 Identity 0.30626
#
# processing ch 106 file 7
#
#         Start/End Query 26651/32684 Target 2/5698 Skipped 4
#         Length 5696/5700 Identity 0.25966
#
# processing ch 106 file 8
#
#         Start/End Query 30839/33764 Target 2/2725 Skipped 4
#         Length 2723/2727 Identity 0.25964
#
# processing ch 106 file 9
#
#         Start/End Query 29411/35631 Target 0/5921 Skipped 1
#         Length 5921/5922 Identity 0.26482
#
#
#         length of all reads 331686
#         length of aligned parts of the reads 313978
#         ratio nucleotides not aligned 0.05339
#         sequence identity of aligned reads 0.27262
#         fully correct kmers 9797
#         ratio fully correct kmers 0.02954
