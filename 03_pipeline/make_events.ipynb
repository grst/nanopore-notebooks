# %%
from nbwrapper import getargs
from multiprocessing import Pool
import pickle
import h5py
import pandas
from pprint import pprint
import re
import os.path
import sys
from itertools import repeat

# %%
args = getargs()
# Out:
# /home/ibis/gregor.sturm/bin/anaconda3/lib/python3.4/site-packages/nbwrapper.py:31: RuntimeWarning: no arguments passed!
#   warnings.warn("no arguments passed!", RuntimeWarning)

# %%
# !pwd
# Out:
# /home/ibis/gregor.sturm/nanopore/own/notebooks

# %%
### for testing only
args = {
    "f5_path": "/home/ibis/gregor.sturm/nanopore/david_eccles_bc_ideas/processed/", ## path to processed f5-files
    "output_basename": "/home/ibis/gregor.sturm/nanopore/own/notebooks/03_pipeline/david_events", 
    "ncores": 24,
}
# args = {
#     "f5_path": "/storageNGS/ngs1/projects/other/NanoporeData/burnin_downloads/", ## path to processed f5-files
#     "output_basename": "/home/ibis/gregor.sturm/nanopore/own/notebooks/03_pipeline/lambda_events", 
#     "ncores": 60,
# }

# %%
assert os.path.isdir(args["f5_path"])
args["ncores"] = int(args["ncores"])
assert args["ncores"]

# %%
SRATE = 5000
NMERS = 5
TYPES = ["template", "complement", "2D"]

# %%
files = !find {args["f5_path"]} | grep fast5
print(len(files))
# Out:
# 6434

# %%
def get_file_and_channel(filename):
    result = re.search(r'ch(\d+)_file(\d+)_', filename)
    file_id = int(result.group(2))
    channel_id = int(result.group(1))
    return file_id, channel_id

# %%
def kmer2move(prev_kmer, curr_kmer):
    """calculates the shift between two kmers. 
    If multiple shifts are possible (repeats), 
    the minimal possible shift is assumed."""
    if(prev_kmer is None): return 0 #first position 
    assert len(prev_kmer) == len(curr_kmer)
    l = len(prev_kmer)
    for i in range(0, l): 
        if prev_kmer[i:] == curr_kmer[:l-i]:
            return i

# %%
def process_metrichor_file(file):
    """
    reads every filename in files with poretools and 
    extracts events and metadata
    """  
    
    tmp_out = []
    
    def log(tmp_out):
        print("\n".join(tmp_out) + "\n")
        sys.stdout.flush()        
        
    file_id, ch_id = get_file_and_channel(file)
    tmp_out.append("processing file {0} channel {1}".format(
        file_id, ch_id))

    f5 = h5py.File(file, 'r')
    fastq = {}
    for t in TYPES: 
        try: 
            fastq[t] = bytes(f5['/Analyses/Basecall_2D_000/BaseCalled_{0}/Fastq'.format(t)][...]).decode('utf-8')
        except KeyError:
            fastq[t] = None           
           
    def process_1d(t): 
        try:
            raw_events = f5['/Analyses/Basecall_2D_000/BaseCalled_{0}/Events'.format(t)] 
        except KeyError:
            return None
        events = []
        tmp_out.append("  >> processing {0} events".format(t))
        for raw_ev in raw_events: 
            ev = {}
            ev["mean"] = raw_ev[0]
            ev["start"] = round(float(raw_ev[1]) * SRATE)
            ev["stdv"] = raw_ev[2]
            ev["end"] = round((float(raw_ev[1]) + float(raw_ev[3])) * SRATE) - 1
            ev["kmer"] = bytes(raw_ev[4]).decode('utf-8')
            ev["move"] = int(raw_ev[6])
            events.append(ev)
        return events   
        
            
    def process_2d(all_events):
        """generate 2d read from alignment and the 1d reads"""
        try:
            aln = f5['/Analyses/Basecall_2D_000/BaseCalled_2D/Alignment']   
        except KeyError:
            return None
        tmp_out.append("  >> processing {0} events".format("2D"))
        events = []
        prev_kmer = None
        for pos in aln:  
            ids = {"template": pos[0], "complement": pos[1]}
            kmer = pos[2]
            move = kmer2move(prev_kmer, kmer)
            prev_kmer = kmer
            ev = {}
            ev["move"] = move
            ev["kmer"] = bytes(kmer).decode('utf-8')
            for t, tmp_id in ids.items():  
                for f in ["mean", "start", "stdv", "end"]:
                    ev["{0}.{1}".format(t, f)] = None if tmp_id < 0 else all_events[t][tmp_id][f]                    
            events.append(ev)
        return events
           
   
      

    all_events = {t: process_1d(t) for t in ["template", "complement"]}
    all_events["2D"] = process_2d(all_events)
    all_events = {t: pandas.DataFrame(events) for t, events in all_events.items()}
      
    
    f_obj = {
        "channel": ch_id,
        "file_id": file_id, 
        "events": all_events,
        "fastq": fastq
    }
    log(tmp_out)
    return f_obj

# %%
p = Pool(args["ncores"])

# %%
try:
    file_data = p.map(process_metrichor_file, files)
except KeyboardInterrupt:
    p.terminate()
# Out:
# processing file 25 channel 154
# processing file 6 channel 190
# processing file 5 channel 102
# processing file 4 channel 179
#   >> processing template events
# processing file 10 channel 216
#   >> processing template events
# processing file 13 channel 188
#   >> processing template events
# processing file 24 channel 236
#   >> processing template events
# processing file 18 channel 235
#   >> processing template events
# processing file 11 channel 20
#   >> processing template events
#   >> processing complement events
# processing file 1 channel 219
#   >> processing template events
# processing file 6 channel 112
#   >> processing template events
# processing file 8 channel 148
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 22 channel 140
#   >> processing template events
# processing file 11 channel 114
#   >> processing template events
# processing file 9 channel 108
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 36 channel 20
#   >> processing template events
# processing file 17 channel 201
#   >> processing template events
# processing file 5 channel 170
#   >> processing template events
#   >> processing complement events
# processing file 15 channel 136
#   >> processing template events
# processing file 10 channel 117
#   >> processing template events
# processing file 38 channel 19
#   >> processing template events
# processing file 16 channel 22
#   >> processing template events
# processing file 7 channel 168
#   >> processing template events
# processing file 8 channel 203
#   >> processing template events
# processing file 10 channel 231
#   >> processing template events
# processing file 14 channel 222
#   >> processing template events
# processing file 24 channel 21
#   >> processing template events
# processing file 15 channel 195
#   >> processing template events
# processing file 0 channel 146
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 3 channel 204
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 26 channel 119
#   >> processing template events
# processing file 20 channel 192
#   >> processing template events
# processing file 15 channel 165
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 7 channel 132
#   >> processing template events
# processing file 4 channel 18
#   >> processing template events
# processing file 16 channel 106
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 0 channel 131
#   >> processing template events
# processing file 16 channel 180
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 16 channel 122
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 4 channel 211
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 3 channel 156
#   >> processing template events
# processing file 3 channel 123
#   >> processing template events
#   >> processing complement events
# processing file 15 channel 224
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 2 channel 210
#   >> processing template events
#   >> processing complement events
# processing file 3 channel 202
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 29 channel 13
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 4 channel 107
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 0 channel 101
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 4 channel 138
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 19 channel 208
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 4 channel 214
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 27 channel 196
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 12 channel 19
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 15 channel 105
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 18 channel 143
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 26 channel 134
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 0 channel 153
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 20 channel 182
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 4 channel 173
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 1 channel 127
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# processing file 29 channel 154
#   >> processing template events
# processing file 7 channel 190
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 6 channel 102
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 5 channel 179
# processing file 13 channel 216
#   >> processing template events
# processing file 14 channel 188
#   >> processing template events
# processing file 25 channel 236
#   >> processing template events
# processing file 19 channel 235
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 12 channel 20
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 20 channel 219
#   >> processing template events
# processing file 8 channel 112
#   >> processing template events
# processing file 9 channel 148
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 24 channel 140
# processing file 12 channel 114
#   >> processing template events
# processing file 0 channel 110
#   >> processing template events
#   >> processing complement events
# processing file 37 channel 20
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 18 channel 201
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 6 channel 170
#   >> processing template events
# processing file 16 channel 136
#   >> processing template events
#   >> processing complement events
# processing file 11 channel 117
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 39 channel 19
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 17 channel 22
#   >> processing template events
# processing file 8 channel 168
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 9 channel 203
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 11 channel 231
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 15 channel 222
#   >> processing template events
# processing file 25 channel 21
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 16 channel 195
#   >> processing template events
# processing file 1 channel 146
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 4 channel 204
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 28 channel 119
#   >> processing template events
# processing file 22 channel 192
#   >> processing template events
# processing file 16 channel 165
#   >> processing template events
# processing file 8 channel 132
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 5 channel 18
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 18 channel 106
#   >> processing template events
#   >> processing complement events
# processing file 10 channel 131
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 17 channel 180
#   >> processing template events
# processing file 17 channel 122
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 5 channel 211
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 0 channel 157
#   >> processing template events
# processing file 4 channel 123
#   >> processing template events
# processing file 16 channel 224
#   >> processing template events
# processing file 3 channel 210
#   >> processing template events
# processing file 4 channel 202
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 2 channel 13
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 6 channel 107
#   >> processing template events
# processing file 11 channel 101
#   >> processing template events
# processing file 5 channel 138
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 1 channel 208
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 5 channel 214
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 29 channel 196
#   >> processing template events
# processing file 13 channel 19
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 16 channel 105
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 19 channel 143
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 27 channel 134
#   >> processing template events
# processing file 11 channel 153
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 22 channel 182
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 6 channel 173
# processing file 2 channel 127
#   >> processing template events
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# processing file 2 channel 154
#   >> processing template events
# processing file 8 channel 190
#   >> processing template events
#   >> processing complement events
# processing file 0 channel 103
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 6 channel 179
#   >> processing template events
# processing file 14 channel 216
#   >> processing template events
# processing file 15 channel 188
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 26 channel 236
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 1 channel 235
#   >> processing template events
# processing file 13 channel 20
#   >> processing template events
# processing file 21 channel 219
#   >> processing template events
#   >> processing complement events
# processing file 9 channel 112
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 0 channel 149
#   >> processing template events
# processing file 26 channel 140
# processing file 13 channel 114
#   >> processing template events
# processing file 1 channel 110
#   >> processing template events
# processing file 38 channel 20
#   >> processing template events
# processing file 1 channel 201
#   >> processing template events
# processing file 7 channel 170
#   >> processing template events
# processing file 18 channel 136
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 12 channel 117
#   >> processing template events
# processing file 3 channel 19
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 18 channel 22
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 9 channel 168
#   >> processing template events
# processing file 0 channel 204
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 12 channel 231
#   >> processing template events
# processing file 16 channel 222
# processing file 26 channel 21
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 18 channel 195
# processing file 2 channel 146
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 5 channel 204
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 29 channel 119
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 23 channel 192
#   >> processing template events
# processing file 18 channel 165
#   >> processing template events
#   >> processing complement events
# processing file 0 channel 133
#   >> processing template events
# processing file 7 channel 18
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 1 channel 106
#   >> processing template events
# processing file 11 channel 131
# processing file 18 channel 180
#   >> processing template events
# processing file 18 channel 122
#   >> processing template events
#   >> processing complement events
# processing file 7 channel 211
#   >> processing template events
# processing file 0 channel 158
#   >> processing template events
# processing file 5 channel 123
#   >> processing template events
#   >> processing complement events
# processing file 17 channel 224
# processing file 4 channel 210
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 6 channel 202
#   >> processing template events
# processing file 31 channel 13
#   >> processing template events
# processing file 8 channel 107
#   >> processing template events
#   >> processing complement events
# processing file 12 channel 101
#   >> processing template events
# processing file 6 channel 138
#   >> processing template events
# processing file 21 channel 208
#   >> processing template events
#   >> processing complement events
# processing file 6 channel 214
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 2 channel 196
#   >> processing template events
#   >> processing complement events
# processing file 15 channel 19
#   >> processing template events
# processing file 17 channel 105
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 22 channel 143
#   >> processing template events
# processing file 2 channel 134
#   >> processing template events
# processing file 12 channel 153
#   >> processing template events
# processing file 23 channel 182
#   >> processing template events
# processing file 8 channel 173
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 4 channel 127
#   >> processing template events

# %%
for t in TYPES:
    tmp_file_data = []
    for f_obj in file_data:
        if f_obj["events"][t] is not None and f_obj["fastq"][t] is not None:
            tmp_f_obj = {
                "channel": f_obj["channel"],
                "file_id": f_obj["file_id"],
                "events": f_obj["events"][t],
                "fastq": f_obj["fastq"][t]
            }
            tmp_file_data.append(tmp_f_obj)       
    filename = "{0}.{1}.pickle".format(args["output_basename"], t)
    pickle.dump(tmp_file_data, open(filename, 'wb'), protocol=2)
# Out:
# processing file 3 channel 154
#   >> processing template events
#   >> processing complement events
# processing file 0 channel 191
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 1 channel 103
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 8 channel 179
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 15 channel 216
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 16 channel 188
#   >> processing template events
# processing file 27 channel 236
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 20 channel 235
#   >> processing template events
# processing file 14 channel 20
#   >> processing template events
# processing file 22 channel 219
#   >> processing template events
# processing file 0 channel 113
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 1 channel 149
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 27 channel 140
#   >> processing template events
#   >> processing complement events
# processing file 14 channel 114
#   >> processing template events
# processing file 2 channel 110
#   >> processing template events
# processing file 3 channel 20
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 20 channel 201
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 9 channel 170
# processing file 1 channel 136
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 13 channel 117
#   >> processing template events
# processing file 41 channel 19
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 1 channel 22
#   >> processing template events
# processing file 0 channel 16
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 10 channel 204
#   >> processing template events
# processing file 13 channel 231
#   >> processing template events
# processing file 17 channel 222
#   >> processing template events
# processing file 28 channel 21
#   >> processing template events
#   >> processing complement events
# processing file 19 channel 195
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 3 channel 146
#   >> processing template events
# processing file 6 channel 204
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 30 channel 119
#   >> processing template events
# processing file 24 channel 192
#   >> processing template events
# processing file 19 channel 165
#   >> processing template events
# processing file 12 channel 133
#   >> processing template events
#   >> processing complement events
# processing file 8 channel 18
#   >> processing template events
# processing file 20 channel 106
#   >> processing template events
#   >> processing complement events
# processing file 13 channel 131
# processing file 19 channel 180
#   >> processing template events
# processing file 19 channel 122
#   >> processing template events
# processing file 8 channel 211
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 1 channel 158
#   >> processing template events
# processing file 7 channel 123
#   >> processing template events
#   >> processing complement events
# processing file 18 channel 224
#   >> processing template events
# processing file 5 channel 210
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 7 channel 202
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 32 channel 13
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 9 channel 107
#   >> processing template events
# processing file 14 channel 101
#   >> processing template events
# processing file 7 channel 138
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 22 channel 208
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 7 channel 214
#   >> processing template events
# processing file 3 channel 196
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 16 channel 19
#   >> processing template events
#   >> processing complement events
# processing file 18 channel 105
#   >> processing template events
# processing file 23 channel 143
#   >> processing template events
# processing file 3 channel 134
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 13 channel 153
#   >> processing template events
# processing file 24 channel 182
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 1 channel 174
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 0 channel 128
#   >> processing template events
#   >> processing complement events
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# processing file 4 channel 154
#   >> processing template events
# processing file 10 channel 191
#   >> processing template events
# processing file 3 channel 103
#   >> processing template events
# processing file 0 channel 17
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 16 channel 216
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 17 channel 188
#   >> processing template events
# processing file 29 channel 236
#   >> processing template events
# processing file 22 channel 235
#   >> processing template events
#   >> processing complement events
# processing file 15 channel 20
#   >> processing template events
# processing file 23 channel 219
#   >> processing template events
# processing file 10 channel 113
#   >> processing template events
# processing file 2 channel 149
#   >> processing template events
#   >> processing complement events
# processing file 2 channel 140
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 15 channel 114
# processing file 0 channel 111
#   >> processing template events
# processing file 41 channel 20
#   >> processing template events
# processing file 21 channel 201
#   >> processing template events
# processing file 0 channel 171
#   >> processing template events
# processing file 2 channel 136
#   >> processing template events
#   >> processing complement events
# processing file 14 channel 117
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 42 channel 19
#   >> processing template events
# processing file 20 channel 22
#   >> processing template events
# processing file 10 channel 16
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 11 channel 204
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 14 channel 231
#   >> processing template events
# processing file 19 channel 222
#   >> processing template events
# processing file 29 channel 21
#   >> processing template events
# processing file 20 channel 195
#   >> processing template events
# processing file 4 channel 146
#   >> processing template events
# processing file 7 channel 204
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 33 channel 119
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 26 channel 192
#   >> processing template events
# processing file 1 channel 165
#   >> processing template events
# processing file 13 channel 133
#   >> processing template events
# processing file 9 channel 18
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 22 channel 106
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 14 channel 131
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 1 channel 180
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 1 channel 122
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 9 channel 211
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 4 channel 158
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 9 channel 123
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 1 channel 224
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 6 channel 210
#   >> processing template events
# processing file 8 channel 202
#   >> processing template events
# processing file 33 channel 13
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 0 channel 108
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 15 channel 101
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 8 channel 138
#   >> processing template events
# processing file 23 channel 208
#   >> processing template events
# processing file 8 channel 214
#   >> processing template events
# processing file 4 channel 196
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 17 channel 19
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 19 channel 105
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 2 channel 143
#   >> processing template events
# processing file 4 channel 134
#   >> processing template events
#   >> processing complement events
# processing file 15 channel 153
#   >> processing template events
# processing file 4 channel 182
#   >> processing template events
# processing file 2 channel 174
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 10 channel 128
#   >> processing template events
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# processing file 5 channel 154
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 11 channel 191
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 5 channel 103
#   >> processing template events
#   >> processing complement events
# processing file 10 channel 17
#   >> processing template events
# processing file 18 channel 216
#   >> processing template events
# processing file 19 channel 188
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 2 channel 236
#   >> processing template events
# processing file 23 channel 235
# processing file 16 channel 20
#   >> processing template events
# processing file 2 channel 219
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 11 channel 113
#   >> processing template events
# processing file 4 channel 149
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 3 channel 140
#   >> processing template events
# processing file 18 channel 114
#   >> processing template events
#   >> processing complement events
# processing file 10 channel 111
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 43 channel 20
#   >> processing template events
# processing file 22 channel 201
#   >> processing template events
# processing file 1 channel 171
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 3 channel 136
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 16 channel 117
#   >> processing template events
# processing file 43 channel 19
#   >> processing template events
# processing file 21 channel 22
#   >> processing template events
# processing file 11 channel 16
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 12 channel 204
# processing file 16 channel 231
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 1 channel 222
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 2 channel 21
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 21 channel 195
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 6 channel 146
#   >> processing template events
# processing file 8 channel 204
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 35 channel 119
#   >> processing template events
#   >> processing complement events
# processing file 3 channel 192
#   >> processing template events
# processing file 21 channel 165
#   >> processing template events
# processing file 16 channel 133
#   >> processing template events
# processing file 10 channel 190
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 23 channel 106
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 1 channel 131
#   >> processing template events
# processing file 20 channel 180
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 21 channel 122
#   >> processing template events
# processing file 0 channel 212
#   >> processing template events
# processing file 5 channel 158
#   >> processing template events
#   >> processing complement events
# processing file 1 channel 125
#   >> processing template events
# processing file 2 channel 224
#   >> processing template events
# processing file 7 channel 210
#   >> processing template events
# processing file 9 channel 202
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 35 channel 13
#   >> processing template events
# processing file 10 channel 108
#   >> processing template events
# processing file 16 channel 101
#   >> processing template events
# processing file 0 channel 139
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 24 channel 208
#   >> processing template events
# processing file 9 channel 214
#   >> processing template events
# processing file 5 channel 196
#   >> processing template events
# processing file 18 channel 19
#   >> processing template events
# processing file 1 channel 105
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 3 channel 143
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 5 channel 134
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 16 channel 153
# processing file 5 channel 182
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 0 channel 175
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
# processing file 11 channel 128
#   >> processing template events
#   >> processing complement events
#   >> processing 2D events
